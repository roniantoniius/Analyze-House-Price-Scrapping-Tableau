# %%
import os
import glob #untuk mengambil semua file dalam satu folder
import requests #supaya bisa mengambil data dari website dengan cara request
import pandas as pd
import numpy as np
import seaborn as sns

# %%
path = 'yourpath'

df = pd.read_csv('data_lamudi.csv')
df
# Out:
#                                                    Nama  \
# 0     Dijual Rumah Strategis Bebas Banjir Pondok Ung...
# 1        Rumah Bintara 2 Lantai Lokasi Baru & Strategis
# 2     Rumah 3 Lantai Strategis di Kota Harapan Indah...
# 3     Jual Cepat rumah di Harapan indah Bekasi Harga...
# 4     Dijual Rumah Siap Huni Tanah Luas di Kota Beka...
# ...                                                 ...
# 7495  Rumah Eksklusif di Sentul Alaya  Lokasi Terbai...
# 7496  Dijual Rumah Murah Siap Huni Dan Sudah Renovas...
# 7497  Dijual Rumah 2 Lantai Di Cluster Siap Huni Dek...
# 7498  Rumah Murah Bebas Banjir Harga Nego Bisa KPR d...
# 7499  Dijual Rumah Murah Sudah Renovasi Dekat Aeon S...
#
#                      Alamat  Kamar Tidur Luas Bangunan Luas Tanah  \
# 0           Babelan, Bekasi            2        100 m²      60 m²
# 1      Bintara Jaya, Bekasi            3         90 m²      60 m²
# 2     Harapan Indah, Bekasi            4        250 m²     163 m²
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nama           7500 non-null   object
#  1   Alamat         7499 non-null   object
#  2   Kamar Tidur    7500 non-null   int64
#  3   Luas Bangunan  7500 non-null   object
#  4   Luas Tanah     7500 non-null   object
#  5   Harga          7478 non-null   object
#  6   Deskripsi      7500 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 410.3+ KB

# %%
df.isnull().sum()
# Out:
# Nama              0
# Alamat            1
# Kamar Tidur       0
# Luas Bangunan     0
# Luas Tanah        0
# Harga            22
# Deskripsi         0
# dtype: int64

# %%
df.dropna(subset=['Harga'], inplace=True)
df.dropna(subset=['Alamat'], inplace=True)

# %%
df.head(3)
# Out:
#                                                 Nama                 Alamat  \
# 0  Dijual Rumah Strategis Bebas Banjir Pondok Ung...        Babelan, Bekasi
# 1     Rumah Bintara 2 Lantai Lokasi Baru & Strategis   Bintara Jaya, Bekasi
# 2  Rumah 3 Lantai Strategis di Kota Harapan Indah...  Harapan Indah, Bekasi
#
#    Kamar Tidur Luas Bangunan Luas Tanah            Harga  \
# 0            2        100 m²      60 m²    Rp560.000.000
# 1            3         90 m²      60 m²    Rp825.000.000
# 2            4        250 m²     163 m²  Rp2.040.000.000
#
#                                            Deskripsi
# 0  Pondok Ungu Permai .Blok AD16 (J-17533) Pondok...
# 1  Di Jual Rumah Bintara Jaya Dekat Ke LRT Cikuni...
# 2  Dijual Cepat Rumah siap huni lokasi strategis,...

# %%
df.Harga.unique()
# Out:
# array(['Rp560.000.000', 'Rp825.000.000', 'Rp2.040.000.000', ...,
#        'Rp838.000.000', 'Rp1.312.600.000', 'Rp707.400.000'], dtype=object)

# %%
df[['LB (m2)', 'Satuan LB']] = df['Luas Bangunan'].str.split("m", expand=True)
df['LB (m2)'] = df['LB (m2)'].astype('float')
del df['Luas Bangunan']
del df['Satuan LB']
df.head(3)
# Out:
#                                                 Nama                 Alamat  \
# 0  Dijual Rumah Strategis Bebas Banjir Pondok Ung...        Babelan, Bekasi
# 1     Rumah Bintara 2 Lantai Lokasi Baru & Strategis   Bintara Jaya, Bekasi
# 2  Rumah 3 Lantai Strategis di Kota Harapan Indah...  Harapan Indah, Bekasi
#
#    Kamar Tidur Luas Tanah            Harga  \
# 0            2      60 m²    Rp560.000.000
# 1            3      60 m²    Rp825.000.000
# 2            4     163 m²  Rp2.040.000.000
#
#                                            Deskripsi  LB (m2)
# 0  Pondok Ungu Permai .Blok AD16 (J-17533) Pondok...    100.0
# 1  Di Jual Rumah Bintara Jaya Dekat Ke LRT Cikuni...     90.0
# 2  Dijual Cepat Rumah siap huni lokasi strategis,...    250.0

# %%
df[['LT (m2)', 'Satuan LT']] = df['Luas Tanah'].str.split("m", expand=True)
df['LT (m2)'] = df['LT (m2)'].astype('float')
del df['Luas Tanah']
del df['Satuan LT']
df.head(3)
# Out:
#                                                 Nama                 Alamat  \
# 0  Dijual Rumah Strategis Bebas Banjir Pondok Ung...        Babelan, Bekasi
# 1     Rumah Bintara 2 Lantai Lokasi Baru & Strategis   Bintara Jaya, Bekasi
# 2  Rumah 3 Lantai Strategis di Kota Harapan Indah...  Harapan Indah, Bekasi
#
#    Kamar Tidur            Harga  \
# 0            2    Rp560.000.000
# 1            3    Rp825.000.000
# 2            4  Rp2.040.000.000
#
#                                            Deskripsi  LB (m2)  LT (m2)
# 0  Pondok Ungu Permai .Blok AD16 (J-17533) Pondok...    100.0     60.0
# 1  Di Jual Rumah Bintara Jaya Dekat Ke LRT Cikuni...     90.0     60.0
# 2  Dijual Cepat Rumah siap huni lokasi strategis,...    250.0    163.0

# %%
df2 = pd.DataFrame(df)
df2
# Out:
#                                                    Nama  \
# 0     Dijual Rumah Strategis Bebas Banjir Pondok Ung...
# 1        Rumah Bintara 2 Lantai Lokasi Baru & Strategis
# 2     Rumah 3 Lantai Strategis di Kota Harapan Indah...
# 3     Jual Cepat rumah di Harapan indah Bekasi Harga...
# 4     Dijual Rumah Siap Huni Tanah Luas di Kota Beka...
# ...                                                 ...
# 7495  Rumah Eksklusif di Sentul Alaya  Lokasi Terbai...
# 7496  Dijual Rumah Murah Siap Huni Dan Sudah Renovas...
# 7497  Dijual Rumah 2 Lantai Di Cluster Siap Huni Dek...
# 7498  Rumah Murah Bebas Banjir Harga Nego Bisa KPR d...
# 7499  Dijual Rumah Murah Sudah Renovasi Dekat Aeon S...
#
#                      Alamat  Kamar Tidur            Harga  \
# 0           Babelan, Bekasi            2    Rp560.000.000
# 1      Bintara Jaya, Bekasi            3    Rp825.000.000
# 2     Harapan Indah, Bekasi            4  Rp2.040.000.000
# ...

# %%
#skip
df[['Kota', 'Kabupaten']] = df['Alamat'].str.split(', ', expand=True)

# %%
df['Harga'] = df['Harga'].str.replace('Rp', '').str.replace('.', '').astype(float)

# %%
df['Harga']
# Out:
# 0       5.600000e+08
# 1       8.250000e+08
# 2       2.040000e+09
# 3       7.550000e+08
# 4       8.600000e+08
#             ...
# 7495    2.350000e+09
# 7496    6.000000e+08
# 7497    8.200000e+08
# 7498    8.000000e+08
# 7499    7.300000e+08
# Name: Harga, Length: 7477, dtype: float64

# 4  Dijual Rumah Siap Huni Tanah Luas di Kota Beka...  Harapan Indah, Bekasi
#
#                                            Deskripsi  Kamar Tidur  LB (m2)  \
# 0  Pondok Ungu Permai .Blok AD16 (J-17533) Pondok...            2    100.0
# 1  Di Jual Rumah Bintara Jaya Dekat Ke LRT Cikuni...            3     90.0
# 2  Dijual Cepat Rumah siap huni lokasi strategis,...            4    250.0
# 3  Lokasi sangat strategis : § Dekat dengan Pusat...            2     84.0
# 4  Perumahan Graha Harapan (J-15927)  MUSTIKAJAYA...            3     95.0
#
#    LT (m2)   Harga
# 0     60.0   560.0
# ...

# %%
df5.isnull().sum()
# Out:
# Nama           0
# Alamat         0
# Deskripsi      0
# Kamar Tidur    0
# LB (m2)        0
# LT (m2)        0
# Harga          0
# dtype: int64

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(user_agent='roniantonius')

# %%
n = nom.geocode("Harapan Indah, Bekasi")

# %%
n.longitude
# Out:
# 106.97581849551752

# %%
df5['Koordinat'] = df5['Alamat'].apply(nom.geocode)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
# ...

# %%
df5['latitude'] = df5['Alamat'].apply(get_latitude)
# Out:
# ---------------------------------------------------------------------------
# AdapterHTTPError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File ~\anaconda3\Lib\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#
# File ~\anaconda3\Lib\site-packages\geopy\adapters.py:500, in RequestsAdapter._request(self, url, timeout, headers)
#     499     if resp.status_code >= 400:
# --> 500         raise AdapterHTTPError(
#     501             "Non-successful status code %s" % resp.status_code,
# ...

# %%
rute = 'data_rumah_jabodetabek_lamudi_2.csv'

# %%
df5.to_csv(rute, index=False)

# %%
df5
# Out:
#                                                    Nama  \
# 0     Dijual Rumah Strategis Bebas Banjir Pondok Ung...
# 1        Rumah Bintara 2 Lantai Lokasi Baru & Strategis
# 2     Rumah 3 Lantai Strategis di Kota Harapan Indah...
# 3     Jual Cepat rumah di Harapan indah Bekasi Harga...
# 4     Dijual Rumah Siap Huni Tanah Luas di Kota Beka...
# ...                                                 ...
# 7495  Rumah Eksklusif di Sentul Alaya  Lokasi Terbai...
# 7496  Dijual Rumah Murah Siap Huni Dan Sudah Renovas...
# 7497  Dijual Rumah 2 Lantai Di Cluster Siap Huni Dek...
# 7498  Rumah Murah Bebas Banjir Harga Nego Bisa KPR d...
# 7499  Dijual Rumah Murah Sudah Renovasi Dekat Aeon S...
#
#                      Alamat  \
# 0           Babelan, Bekasi
# 1      Bintara Jaya, Bekasi
# 2     Harapan Indah, Bekasi
# 3     Harapan Indah, Bekasi
# 4     Harapan Indah, Bekasi
# ...                     ...
# 7495          Sentul, Bogor
# 7496          Parung, Bogor
# ...

# %%
df5

# %% [markdown]
# ### Perbaikan
# - Kolom Alamat dipisah menjadi kolom kota dan kabupaten
# - Kolom Luas Bangunan dan Luas Tanah akan diubah menjadi tipe data integer atau float tanpa m^2
# - Kolom Harga akan menjadi float/int dan diubah kedalam skala juta
# - Membuat kolom lat dan long berdasarkan Alamat
